# %% [markdown]
# ## Conversion of raw ADCP data to Netcdf

# %%
from mhkit import dolfyn

# %%
ds_08 = dolfyn.read('../../../data/ADCP/S102994A008_Underwater.ad2cp')[1]
ds_11 = dolfyn.read('../../../data/ADCP/S102994A011_Underwater.ad2cp')[1]
ds_08
# Out:
# Dual Profile detected... Two datasets will be returned.
# Reading file ../../../data/ADCP/S102994A008_Underwater.ad2cp ...
# Indexing ../../../data/ADCP/S102994A011_Underwater.ad2cp...
# c:\Users\karoa\miniconda3\envs\mhkit\Lib\site-packages\mhkit\dolfyn\io\nortek2_lib.py:304: UserWarning: Dual Profile detected... Two datasets will be returned.
#   warnings.warn(msg)
# Dual Profile detected... Two datasets will be returned.
#  Done.
# Reading file ../../../data/ADCP/S102994A011_Underwater.ad2cp ...
# <xarray.Dataset> Size: 74MB
# Dimensions:              (time_avg: 52973, dirIMU: 3, range_avg: 35, dir: 4,
#                           beam: 4, earth: 3, inst: 3, q: 4, x1: 4, x2: 4)
# Coordinates:
#   * time_avg             (time_avg) datetime64[ns] 424kB 2023-01-13T14:00:00....
#   * dirIMU               (dirIMU) <U1 12B 'E' 'N' 'U'
#   * range_avg            (range_avg) float64 280B 1.5 2.5 3.5 ... 33.5 34.5 35.5
#   * dir                  (dir) <U2 32B 'E' 'N' 'U1' 'U2'
# ...

# %%
dolfyn.save(ds_08, '../../../data/ADCP/S102994A008_Underwater.nc')  
dolfyn.save(ds_11, '../../../data/ADCP/S102994A011_Underwater.nc')
# Out:
# c:\Users\karoa\miniconda3\envs\mhkit\Lib\site-packages\mhkit\dolfyn\io\api.py:223: UserWarning: Times can't be serialized faithfully to int64 with requested units 'seconds since 1970-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   ds.to_netcdf(filename, format=format, engine=engine, **kwargs)
# c:\Users\karoa\miniconda3\envs\mhkit\Lib\site-packages\mhkit\dolfyn\io\api.py:223: UserWarning: Times can't be serialized faithfully to int64 with requested units 'seconds since 1970-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   ds.to_netcdf(filename, format=format, engine=engine, **kwargs)
